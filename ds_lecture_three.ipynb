# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlalchemy
plt.style.use('bmh')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_119798/3132712483.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import sqlalchemy
# ----> 5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ==========================
# Data Visualisation. Exploratory Data Analysis
# ==========================

# %%
whr_2019 = pd.read_csv('data/ds_l3/2019.csv')
whr_2018 = pd.read_csv('data/ds_l3/2018.csv')
whr_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
whr_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
plt.hist(whr_2018['GDP per capita'], bins='fd')
plt.xlabel('GDP Contribution')
plt.ylabel('Count')
plt.show()

# %%
whr_2018['GDP per capita'].mean()
# Out:
# 0.8914487179487179

# %%
whr_2018[(whr_2018['GDP per capita'] > 1.5) & (whr_2018['GDP per capita'] < 2)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 16            17        Luxembourg  6.910           1.576           1.520
# 31            32             Qatar  6.374           1.649           1.303
# 33            34         Singapore  6.343           1.529           1.451
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 16                    0.896                         0.632       0.196
# 31                    0.748                         0.654       0.256
# 33                    1.008                         0.631       0.261
#
#     Perceptions of corruption
# 16                      0.321
# 31                      0.171
# 33                      0.457

# %%
whr_2018[(whr_2019['GDP per capita'] > 1.5) & (whr_2019['GDP per capita'] < 2)]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 13            14           Ireland  6.977           1.448           1.583
# 20            21    Czech Republic  6.711           1.233           1.489
# 28            29         Argentina  6.388           1.073           1.468
# 33            34         Singapore  6.343           1.529           1.451
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 13                    0.876                         0.614       0.307
# 20                    0.854                         0.543       0.064
# 28                    0.744                         0.570       0.062
# 33                    1.008                         0.631       0.261
#
#     Perceptions of corruption
# 13                      0.306
# 20                      0.034
# 28                      0.054
# 33                      0.457

# %%
whr_2018.nsmallest(10, 'GDP per capita')
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 97             98                   Somalia  4.982           0.000
# 154           155  Central African Republic  3.083           0.024
# 131           132          Congo (Kinshasa)  4.245           0.069
# 148           149                   Liberia  3.495           0.076
# 155           156                   Burundi  2.905           0.091
# 133           134                     Niger  4.166           0.131
# 146           147                    Malawi  3.587           0.186
# 122           123                Mozambique  4.417           0.198
# 112           113              Sierra Leone  4.571           0.256
# 138           139                      Togo  3.999           0.259
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 97            0.712                    0.115                         0.674
# 154           0.000                    0.010                         0.305
# ...

# %%
plt.hist(whr_2018.nsmallest(20, 'GDP per capita')['GDP per capita'])  # , bins = 'fd'
plt.xlabel('GDP Contribution')
plt.ylabel('Countries Count')
plt.show()
# From select ten min 'GDP per capita' values and get from them ['GDP per capita'] and create graph!

# %%
whr_2018[whr_2018['GDP per capita'] > 1.5]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 16            17            Luxembourg  6.910           1.576           1.520
# 19            20  United Arab Emirates  6.774           2.096           0.776
# 31            32                 Qatar  6.374           1.649           1.303
# 33            34             Singapore  6.343           1.529           1.451
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 16                    0.896                         0.632       0.196
# 19                    0.670                         0.284       0.186
# 31                    0.748                         0.654       0.256
# 33                    1.008                         0.631       0.261
#
#     Perceptions of corruption
# 16                      0.321
# 19                        NaN
# 31                      0.171
# 33                      0.457

# %%
whr_2019[whr_2019['GDP per capita'] > 1.5]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 13            14            Luxembourg  7.090           1.609           1.479
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 28            29                 Qatar  6.374           1.684           1.313
# 33            34             Singapore  6.262           1.572           1.463
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 13                    1.012                         0.526       0.194
# 20                    0.825                         0.598       0.262
# 28                    0.871                         0.555       0.220
# 33                    1.141                         0.556       0.271
#
#     Perceptions of corruption
# 13                      0.316
# 20                      0.182
# 28                      0.167
# 33                      0.453

# %%
plt.hist(whr_2018['GDP per capita'], bins = 20, alpha = 0.7, label= '2018')
plt.hist(whr_2019['GDP per capita'], bins = 20, alpha = 0.7, label= '2018')
plt.legend()
plt.xlabel('GDP Contribution')
plt.ylabel('Countries Count')
plt.show()

# %%
plt.hist(whr_2018['Score'], bins = 20, alpha = 0.7, label= '2018')
plt.hist(whr_2019['Score'], bins = 20, alpha = 0.7, label= '2018')
plt.legend()
plt.xlabel('Score')
plt.ylabel('Countries Count')
plt.show()

# %%
plt.boxplot([whr_2018['Score'], whr_2019['Score']])
plt.xticks([1,2], ['2018', '2019'])
plt.show()

# %%
whr_merged = whr_2018.merge(whr_2019, left_on='Country or region', right_on='Country or region', suffixes = ('_2018', '_2019'))
whr_merged
# Out:
#      Overall rank_2018         Country or region  Score_2018  \
# 0                    1                   Finland       7.632
# 1                    2                    Norway       7.594
# 2                    3                   Denmark       7.555
# 3                    4                   Iceland       7.495
# 4                    5               Switzerland       7.487
# ..                 ...                       ...         ...
# 147                152                     Yemen       3.355
# 148                153                  Tanzania       3.303
# 149                154               South Sudan       3.254
# 150                155  Central African Republic       3.083
# 151                156                   Burundi       2.905
#
#      GDP per capita_2018  Social support_2018  Healthy life expectancy_2018  \
# 0                  1.305                1.592                         0.874
# 1                  1.456                1.582                         0.861
# ...

# %%
scores = whr_merged[['Country or region', 'Score_2018', 'Score_2019']]
scores_max = scores.nlargest(15, 'Score_2018')
scores_min = scores.nsmallest(15, 'Score_2018')

# %%
plt.figure(figsize=(20, 11))   # Defines size of the image in inches
plt.barh(scores_min['Country or region'], scores_min['Score_2018'], label='min 15')
plt.barh(scores_max['Country or region'], scores_max['Score_2018'],label='max 15')
plt.legend(loc='upper right',)
plt.gca().invert_yaxis()
plt.xlim(0, 8)
plt.ylim(0, 30)
# Out:
# (0.0, 30.0)

# %%
plt.barh(scores_max['Country or region'], scores_max['Score_2018'],)
plt.gca().invert_yaxis()
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)

# %%
plt.barh(scores_min['Country or region'], scores_min['Score_2018'],)
plt.gca().invert_yaxis()
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)

# %%
bg_scores = scores[scores['Country or region'] == 'Bulgaria'].T.drop('Country or region').values.ravel() 
ro_scores = scores[scores['Country or region'] == 'Romania'].T.drop('Country or region').values.ravel() 
bg_scores
# Out:
# array([4.933, 5.011], dtype=object)

# %%
years = list(range(2017,2019))

# %%
plt.figure(figsize=(8, 8))   # Defines size of the image in inches

plt.scatter(years, bg_scores, marker = 's', s = 50)   # First plot
plt.plot(years, bg_scores, linewidth = 5, linestyle = 'dashed')    # Combined with second plot

plt.scatter(years, ro_scores, marker = 's', s = 50)   # First plot
plt.plot(years, ro_scores, linewidth = 5, linestyle = 'dashed')    # Combined with second plot

plt.title('Bulgaria and Romania')
plt.xlabel('year')
plt.ylabel('score')
plt.xticks(years)
plt.legend(loc = 'upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
